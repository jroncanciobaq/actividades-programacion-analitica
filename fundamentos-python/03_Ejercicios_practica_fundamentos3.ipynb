# %%
#A. Definir y llamar

# %%
#Complete la palabra clave que define una función.

def saludar():
    print('Hola')
    
saludar()
# Out:
# Hola

# %%
#Complete la línea que ejecuta la función ya definida.

def bienvenida():
    print('Bienvenido al curso')
    
bienvenida()
# Out:
# Bienvenido al curso

# %%
#Sin ejecutar, determine en qué orden aparecen los mensajes

def uno():
    print('A')
    
print('B')
uno()
print('C')

#El primero que sale es 'B', luego imprime 'A' y al final imprime 'C'
# Out:
# B
# A
# C

# %%
#El programa falla porque la función se llama antes de existir. Reescriba el bloque completo en el orden correcto

def saludar(nombre):
    print('Hola,', nombre)
    
saludar('Ana')
# Out:
# Hola, Ana

# %%
#Complete el parámetro que recibe la función.

def saludar(nombre):
    print('Hola,', nombre)

saludar('Ana')
# Out:
# Hola, Ana

# %%
#Complete los parámetros necesarios para calcular el área.

def area(base,altura):
    return base*altura

print(area(3,4))
# Out:
# 12

# %%
#Complete los argumentos para obtener exactamente el resultado indicado.

def area(base, altura):
    return base*altura

print(area(5,5))
# Out:
# 25

# %%
#Llame tres veces a la misma función con precios distintos.

def con_iva(precio):
    return precio * 1.19

print(con_iva(10))
print(con_iva(80))
print(con_iva(50))
# Out:
# 11.899999999999999
# 95.19999999999999
# 59.5

# %%
#B. Parametros y argumentos

# %%
#Observe la definición y la llamada, y distinga cada uno de los dos nombres

def doble(n):
    return n*2
resultado = doble(5)

#n es el parametro y 5 es el argumento

# %%
#Complete la llamada para que se imprima: Ana 20 Bogota

def perfil(nombre, edad, ciudad):
    print(nombre, edad, ciudad)
    
perfil('Ana', 20, 'Bogota')
# Out:
# Ana 20 Bogota

# %%
#Complete los nombres de los parámetros para que el orden deje de importar.

def perfil(nombre, edad, ciudad):
    print(nombre, edad, ciudad)

perfil(edad=20, nombre='Ana', ciudad='Bogota' )
# Out:
# Ana 20 Bogota

# %%
#Complete el valor por defecto del parámetro saludo

def saludar(nombre, saludo='Hola'):
    print(saludo, nombre)
    
saludar('Ana')
# Out:
# Hola Ana

# %%
#Complete el argumento que sustituye al saludo por defecto

def saludar(nombre, saludo='Hola'):
    print(saludo, nombre)
    
saludar('Luis', saludo= 'Buen dia')
# Out:
# Buen dia Luis

# %%
#El siguiente encabezado produce un error. Reescriba la definición completa de forma correcta.

def registrar(cantidad, producto): #Al principio se esta definiendo la funcion con los parametros, pero no se debe establecer el argumento de los parametros que se definen en la función como tal, es necesario definir los argumentos (valores) al final

    print(producto, cantidad=1)

# %%
#Complete el recorrido para sumar todos los precios recibidos.

def total (precios):
    suma=0
    for p in precios:
        suma= suma+p
    return suma

print(total([1200, 950, 3400]))
# Out:
# 5550

# %%
#C. Return y resultado

# %%
#Complete la palabra clave que entrega el resultado

def doble(n):
    return(n*2)

print(doble(5))
# Out:
# 10

# %%
#Complete la llamada para guardar el resultado y operar con él.

def doble(n):
    return n*2

resultado=doble(6)
print(resultado+1)
# Out:
# 13

# %%
#Sin ejecutar, determine qué imprimen las dos últimas líneas.

def saludo(nombre):
    print('Hola,', nombre)
    
x= saludo('Ana') #muestra Hola, Ana

print(x) #para que muestre Hola, Ana es necesario reemplazar el print por el return

# %%
#La suma falla. Corrija la función para que el resultado pueda seguir usándose y escriba la versión corregida

def doble(n):
    return(n*2)

total=doble(5)+3

print(total)
# Out:
# 13

# %%
#Complete la instrucción que devuelve el segundo resultado.

def signo(n):
    if n < 0:
        return 'negativo'
    return 'positivo'
    
print(signo(-4))
print(signo(7))
# Out:
# negativo
# positivo

# %%
#Sin ejecutar, determine qué se imprime y qué línea nunca se ejecuta.

def prueba(n):
    if n>0:
        return'Positivo'
    print('linea intermedia') #no aparece 'linea intermedia' ya que  la idea es que retorne un valor y print imprime una variable
    return'otro'

print(prueba(5))
# Out:
# Positivo

# %%
#Complete la función para que entregue el mínimo y el máximo.

def resumen(valores):
    return min(valores), max(valores)

menor, mayor = resumen([8,3,10,5])
print(menor, mayor)
# Out:
# 3 10

# %%
#Complete la llamada interna para calcular el precio con IVA redondeado.

def con_iva(p):
    return p*1.19

def redondear(valor):
    return round(valor, 2)
print(redondear(con_iva(1200)))
# Out:
# 1428.0

# %%
#D. Ambito y colecciones

# %%
#Sin ejecutar, determine qué imprime cada una de las dos llamadas.

mensaje = 'global' #se define la variable mensaje como global

def prueba():
    mensaje = 'local' #se define la variable mensaje como local dentro de la función
    print(mensaje)
    
prueba() #muestra local porque se esta llamando la función
print(mensaje) #muestra global porque esta llamando a la variable mensaje que está afuera de la funcion prueba

# %%
#Reescriba la función para que reciba el IVA como parámetro y no dependa de una variable externa.

def con_iva(precio, iva=0.19):
    return precio *(1+iva)
print(con_iva(1))
# Out:
# 1.19

# %%
#Complete la función para que devuelva una lista nueva sin alterar la que recibe.

def agregar (lista):
    nueva = lista + [3]
    return nueva

datos=[1, 2]
print(agregar(datos))

print(datos)
# Out:
# [1, 2, 3]
# [1, 2]

# %%
#Complete la función que calcula el promedio de una lista de notas.

def promedio(notas):
    total = 0
    for n in notas:
        total=total+n
    return total/len(notas)

print(promedio([3.5, 4.2, 2.8]))
# Out:
# 3.5

# %%
#Complete las claves para mostrar el nombre y la nota del estudiante

def describir(alumno):
    print(alumno['nombre'], alumno['nota'])
    
describir({'nombre': 'Laura', 'nota': 4.6})
# Out:
# Laura 4.6

# %%
#Complete el método que agrega elementos y el valor que se devuelve.

def aprobados(estudiantes):
    resultado = []
    for e in estudiantes:
        if e['nota']>=3.0:
            resultado.append(e['nombre'])
    return resultado

datos = [{'nombre':'Ana', 'nota': 4.2},
         {'nombre':'Luis', 'nota': 2.8}]

print(aprobados(datos))
# Out:
# ['Ana']

# %%
#Complete el método que agrega elementos y el valor que se devuelve.

def promedio(notas):
    total = 0
    for n in notas:
        total = total + n
    return total / len (notas)

def aprueba(prom, minimo= 3.0):
    return prom > minimo

def reporte(nombre, notas):
    prom= promedio(notas)
    print(nombre, round(prom, 2))
    if  aprueba(prom):
        print('Aprobado')
    else:
        print('No Aprobado')
        
reporte('Laura', [3.5, 4.2, 2.8])
# Out:
# Laura 3.5
# Aprobado
