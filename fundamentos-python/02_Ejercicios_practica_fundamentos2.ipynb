# %%
print('Hola')
# Out:
# Hola

# %%
#%% A. Listas

# %%
#Complete la lista con cinco notas y muestre la cantidad de elementos

notas=[3.5, 4.0, 5.0, 3.0, 4.5]
print(len(notas))
print(notas)
# Out:
# 5
# [3.5, 4.0, 5.0, 3.0, 4.5]

# %%
#Use índices para imprimir la primera, la tercera y la última temperatura.

temperaturas= [18, 20, 19, 21, 22]

print(temperaturas[0])
print(temperaturas[2])
print(temperaturas[4])
# Out:
# 18
# 19
# 22

# %%
#Corrija la segunda venta, que fue registrada como 80 pero debía ser 85.

ventas = [120, 80, 200, 50]

ventas[1]=85
print(ventas)
# Out:
# [120, 85, 200, 50]

# %%
#Agregue una nueva nota y extraiga la última nota registrada.

notas=[3.5, 4.0, 2.8]

notas.append(4.6)
ultima=notas.pop()

print(ultima)
print(notas)
# Out:
# 4.6
# [3.5, 4.0, 2.8]

# %%
#Complete el acumulador para calcular el promedio de una lista.

notas=[4.2, 3.8, 5.0, 2.9]
total=0

for nota in notas:
    total = total + nota
    
promedio=total/len(notas)
print(round(promedio,2))
# Out:
# 3.98

# %%
#Cuente cuántas notas son mayores o iguales a 3.0

notas=[4.2, 2.5, 3.0, 1.8, 4.7]
aprobados=0

for nota in notas:
    if nota>=3.0:
        aprobados = aprobados + 1
print(aprobados)
# Out:
# 3

# %%
#Construya una lista con las temperaturas que estén entre -10 y 50 grados.

lecturas=[18, 200, 21, -99, 19, 22]

validas=[]

for t in lecturas:
    if t>=-10 and t<=50:
        validas.append(t)
        
print(validas)
# Out:
# [18, 21, 19, 22]

# %%
#Use sorted() para crear una lista ordenada sin modificar la lista inicial.

montos=[120000, 85000, 50000]

ordenados=sorted(montos) #ordena de mayor a menor

print(montos)
print(ordenados)
# Out:
# [120000, 85000, 50000]
# [50000, 85000, 120000]

# %%
#Complete la comprensión para obtener los cuadrados de los números pares

numeros=[1, 2, 3, 4, 5, 6]

cuadrados_pares = [n**2 for n in numeros if n % 2 ==0]
print(cuadrados_pares)
# Out:
# [4, 16, 36]

# %%
#Complete el doble ciclo para sumar todos los elementos de una matriz.

matriz=[[1,2,3], [4,5,6]]
total=0

for fila in matriz:#Recorre los valores de la matriz general
    for valor in fila:#Recorre los valores de cada lista
        total += valor#genera la suma acumulada

print(total)
# Out:
# 21

# %%
#%%Tuplas

# %%
#Defina una tupla con la latitud y la longitud de una sede.

ubicacion=(-75,8)
print(ubicacion)
print(type(ubicacion))
# Out:
# (-75, 8)
# <class 'tuple'>

# %%
#Asigne los elementos de la tupla a variables con nombres significativos

registro = ('A01', 'Laura', 4.6)
curso, nombre, nota=registro

print(nombre)
print(nota)
print(curso)
# Out:
# Laura
# 4.6
# A01

# %%
#Complete la sintaxis correcta de una tupla que contiene un solo código.

codigo = ('A01',)

print(codigo)
print(type(codigo))
# Out:
# ('A01',)
# <class 'tuple'>

# %%
#Convierta una lista de columnas a tupla para evitar cambios accidentales.

columnas= ['fecha', 'monto', 'cliente']

columnas_fijas=tuple(columnas)
print(columnas_fijas)
# Out:
# ('fecha', 'monto', 'cliente')

# %%
#Complete una función que retorne el mínimo y el máximo como una tupla implícita.

def resumen (valores):
    menor = min(valores)
    mayor = max(valores)
    return menor, mayor

minimo, maximo = resumen([8, 3, 10, 5])
print(minimo, maximo)
# Out:
# 3 10

# %%
#Ejecute mentalmente el código y explique qué error se produce

punto(10, 20)

punto[0] = 99
print(punto)

#como es una tupla, no se puede adicionar el elemento 99 en la posición 0, es decir de primero. si fuera una lista si se realizaría el proceso
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 #Ejecute mentalmente el código y explique qué error se produce
#       2
# ----> 3 punto(10, 20)
#       4
#       5 punto[0] = 99
#       6 print(punto)
#
# NameError: name 'punto' is not defined

# %%
#Use una tupla como clave para almacenar una lectura por coordenada.

lecturas={}
coordenada=(4.65, -74.05)

lecturas[coordenada] = 18.5
print(lecturas[(4.65, -74.05)])
# Out:
# 18.5

# %%
#Cree pares estudiante-nota usando zip() y conviértalos a lista.

nombres=['Ana', 'Luis', 'Marta']
notas=[4.2, 3.8, 5.0]

pares = list(zip(nombres, notas)) #Lo que realiza zip es agrupar listas en una sola

print(pares)
# Out:
# [('Ana', 4.2), ('Luis', 3.8), ('Marta', 5.0)]

# %%
#%%Diccionarios

# %%
#Complete las claves necesarias para representar a un estudiante

estudiante={
    'codigo':'A01', #Para crear las claves en los diccionarios, deben como si fueran tipo texto
    'nombre':'Laura',
    'nota':4.6
}

print(estudiante)
# Out:
# {'codigo': 'A01', 'nombre': 'Laura', 'nota': 4.6}

# %%
#Use get() para consultar una clave que podría no existir.


cliente={'nombre':'Carlos', 'Puntaje': 720}

saldo=cliente.get('saldo', 0) #lo que realiza .get es extraer información de una llave en un diccionario; en este caso como no existe la clave, no muestra información asociada
 
print(saldo)
# Out:
# Carlos

# %%
#Actualice el stock de un producto después de una venta de 3 unidades.

producto = {'codigo': 'P01', 'stock': 8}

producto['stock']=producto['stock'] - 3
print(producto['stock'])
# Out:
# 5

# %%
#Complete el recorrido para imprimir cada atributo con su valor.

producto = {'codigo':'P01', 'precio': 12000, 'stock': 8}

for clave, valor in producto.items():#.items() extrae cada clave y su correspondiente valor
    print(clave, valor)
# Out:
# codigo P01
# precio 12000
# stock 8

# %%
# Use un diccionario acumulador para contar los tipos de transacción

tipos=['Debito', 'Credito', 'Debito', 'Debito','Credito']

conteo={}

for tipo in tipos:
    conteo[tipo]=conteo.get(tipo, 0) + 1 #Lo que realiza esta parte es generar un contador acumulado que me indica cuantas veces se repite 'Debito' y 'Credito'
    
    print(conteo)
# Out:
# {'Debito': 1}
# {'Debito': 1, 'Credito': 1}
# {'Debito': 2, 'Credito': 1}
# {'Debito': 3, 'Credito': 1}
# {'Debito': 3, 'Credito': 2}

# %%
#Acceda a la nota de Laura dentro de una estructura anidada.

grupo={
    'A01':{'nombre': 'Laura', 'nota': 4.6},
    'A02':{'nombre': 'Luis', 'nota': 3.8}
}

print(grupo['A01']['nota'])
# Out:
# 4.6

# %%
#Calcule el total de los montos en una lista de transacciones

transacciones=[
    {'id': 'T01', 'monto': 120000},
    {'id': 'T02', 'monto': 85000},
    {'id': 'T03', 'monto': 210000}
]

total=0

for t in transacciones:
    total +=t['monto']
print(total)
# Out:
# 415000

# %%
#Complete una búsqueda lineal sobre una lista de diccionarios.

estudiantes=[
    {'codigo':'A01', 'nombre':'Laura'},
    {'codigo':'A02', 'nombre':'Luis'}
]

buscando='A02'
resultado=None

for e in estudiantes:
    if e ['codigo'] == 'A02':
        resultado = e['nombre']
print(resultado)
# Out:
# Luis

# %%
#Construya una lista con los nombres de los estudiantes aprobados.

estudiantes=[
    {'nombre':'Ana', 'nota':4.2},
    {'nombre':'Luis', 'nota':2.8},
    {'nombre':'Marta', 'nota':3.5}
]

aprobados = [] #se crea una lista con los nombre extraidos en el for

for e in estudiantes:
    if e['nota'] >=3.0: #busca estudiantes cuya nota sea mayor o igual a 3.0
        aprobados.append(e['nombre'])#extrae solo los nombres de la consulta del for y los guarda en la lista 'aprobados'
        
print(aprobados)
# Out:
# ['Ana', 'Marta']

# %%
#Agrupe los nombres de los clientes según su nivel de riesgo.

clientes = [
 {"nombre": "Ana", "riesgo": "bajo"},
 {"nombre": "Luis", "riesgo": "alto"},
 {"nombre": "Marta", "riesgo": "bajo"}
]
grupo = {} #guarda los valores de la lista en un diccionario
for c in clientes:
 riesgo = c["riesgo"]
 if riesgo not in grupo:
     grupo[riesgo] = [] #verifica si los valores de las claves riesgo existe, como al principio no hay nada, el valor de riesgo = bajo se cumple y lo registra, en el segundo caso de riesgo = alto, como no se encuentra lo crea, pero en el tercer caso como riesgo = bajo ya está pues no es necesario crearlo nuevamente y todo esto lo guarda en una lista
 grupo[riesgo].append(c['nombre'])#a esta lista creada previamente con los valores de riesgo, les adiciona los nombres de cada riesgo asociado
print(grupo)
# Out:
# {'bajo': ['Ana', 'Marta'], 'alto': ['Luis']}

# %%
#Complete el reporte de los productos con stock bajo.

inventario = [
    {'producto' : 'Marcador', 'stock' : 4},
    {'producto' : 'Cuaderno', 'stock' : 20},
    {'producto' : 'Borrador', 'stock' : 2}
]

bajos=[]

for item in inventario:
    if item['stock']<10: #al no existir un criterio para considerar un stock bajo se definió como stock bajos aquellos productos menor a 10 unidades
        bajos.append(item['producto'])
print(bajos)
# Out:
# ['Marcador', 'Borrador']

# %%
#Complete el algoritmo que calcula el total de los créditos mayores o iguales a 100000 y registra los clientes correspondientes.


transacciones = [
    {'cliente':'Ana', 'tipo': 'Credito', 'monto': 120000},
    {'cliente':'Luis', 'tipo': 'Debito', 'monto': 85000},
    {'cliente':'Marta', 'tipo': 'Credito', 'monto': 210000}
]

total_creditos = 0
clientes=[]

for t in transacciones:
    if t['tipo'] == 'Credito' and t['monto'] >=100000:
        total_creditos += t['monto']
        clientes.append(t['cliente'])

print(total_creditos)
print(clientes)
# Out:
# 330000
# ['Ana', 'Marta']
